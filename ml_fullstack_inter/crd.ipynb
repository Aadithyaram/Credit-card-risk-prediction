# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("E:\ml_fullstack_inter\data\customer_data.csv")
df2 = pd.read_csv("E:\ml_fullstack_inter\data\payment_data.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1125 entries, 0 to 1124
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   1125 non-null   int64
#  1   id      1125 non-null   int64
#  2   fea_1   1125 non-null   int64
#  3   fea_2   976 non-null    float64
#  4   fea_3   1125 non-null   int64
#  5   fea_4   1125 non-null   float64
#  6   fea_5   1125 non-null   int64
#  7   fea_6   1125 non-null   int64
#  8   fea_7   1125 non-null   int64
#  9   fea_8   1125 non-null   int64
#  10  fea_9   1125 non-null   int64
#  11  fea_10  1125 non-null   int64
#  12  fea_11  1125 non-null   float64
# dtypes: float64(3), int64(10)
# memory usage: 114.4 KB

# %%
df1
# Out:
#       label        id  fea_1   fea_2  fea_3     fea_4  fea_5  fea_6  fea_7  \
# 0         1  54982665      5  1245.5      3   77000.0      2     15      5
# 1         0  59004779      4  1277.0      1  113000.0      2      8     -1
# 2         0  58990862      7  1298.0      1  110000.0      2     11     -1
# 3         1  58995168      7  1335.5      1  151000.0      2     11      5
# 4         0  54987320      7     NaN      2   59000.0      2     11      5
# ...     ...       ...    ...     ...    ...       ...    ...    ...    ...
# 1120      0  58988196      5  1289.0      1  173000.0      2     15      5
# 1121      0  58987926      5     NaN      2   50000.0      2     15      5
# 1122      0  58995381      7  1220.0      3   76000.0      2     11      2
# 1123      0  58998054      4  1250.0      3  137000.0      2      8      5
# 1124      0  54989781      4  1415.0      3   93000.0      2      8      5
#
#       fea_8  fea_9  fea_10      fea_11
# 0       109      5  151300  244.948974
# 1       100      3  341759  207.173840
# 2       101      5   72001    1.000000
# 3       110      3   60084    1.000000
# 4       108      4  450081  197.403141
# ...     ...    ...     ...         ...
# 1120    112      3  350702  200.000000
# 1121    108      4  450000  169.000000
# 1122     90      5   71002    1.000000
# 1123     90      5   72000    1.000000
# 1124    113      4  151300  273.861279
#
# [1125 rows x 13 columns]

# %%
df2
# Out:
#             id  OVD_t1  OVD_t2  OVD_t3  OVD_sum  pay_normal  prod_code  \
# 0     58987402       0       0       0        0           1         10
# 1     58995151       0       0       0        0           1          5
# 2     58997200       0       0       0        0           2          5
# 3     54988608       0       0       0        0           3         10
# 4     54987763       0       0       0        0           2         10
# ...        ...     ...     ...     ...      ...         ...        ...
# 8245  58995478       0       0       0        0           9         15
# 8246  54992408       0       0       0        0           1          2
# 8247  54988209       0       0       0        0           5         13
# 8248  54992408       0       0       0        0           1          2
# 8249  54989207       0       0       0        0           1          5
#
#       prod_limit update_date  new_balance  highest_balance report_date
# 0        16500.0  04/12/2016          0.0              NaN         NaN
# 1            NaN  04/12/2016     588720.0         491100.0         NaN
# 2            NaN  04/12/2016     840000.0         700500.0  22/04/2016
# 3        37400.0  03/12/2016       8425.2           7520.0  25/04/2016
# 4            NaN  03/12/2016      15147.6              NaN  26/04/2016
# ...          ...         ...          ...              ...         ...
# 8245         NaN         NaN          0.0              NaN         NaN
# 8246         NaN         NaN          0.0              NaN         NaN
# 8247         NaN         NaN      20654.4          33315.0         NaN
# 8248         NaN         NaN          0.0              NaN         NaN
# 8249         NaN         NaN     240000.0         200500.0         NaN
#
# [8250 rows x 12 columns]

# %%
for i in df1.columns:
    values = df1[i].value_counts
    print(values)
# Out:
# <bound method IndexOpsMixin.value_counts of 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 1120    0
# 1121    0
# 1122    0
# 1123    0
# 1124    0
# Name: label, Length: 1125, dtype: int64>
# <bound method IndexOpsMixin.value_counts of 0       54982665
# 1       59004779
# 2       58990862
# 3       58995168
# 4       54987320
#           ...
# 1120    58988196
# 1121    58987926
# 1122    58995381
# 1123    58998054
# 1124    54989781
# Name: id, Length: 1125, dtype: int64>
# <bound method IndexOpsMixin.value_counts of 0       5
# 1       4
# 2       7
# 3       7
# 4       7
#        ..
# 1120    5
# 1121    5
# 1122    7
# 1123    4
# 1124    4
# Name: fea_1, Length: 1125, dtype: int64>
# <bound method IndexOpsMixin.value_counts of 0       1245.5
# 1       1277.0
# 2       1298.0
# 3       1335.5
# 4          NaN
#          ...
# 1120    1289.0
# 1121       NaN
# 1122    1220.0
# 1123    1250.0
# 1124    1415.0
# Name: fea_2, Length: 1125, dtype: float64>
# <bound method IndexOpsMixin.value_counts of 0       3
# 1       1
# 2       1
# 3       1
# 4       2
#        ..
# 1120    1
# 1121    2
# 1122    3
# 1123    3
# 1124    3
# Name: fea_3, Length: 1125, dtype: int64>
# <bound method IndexOpsMixin.value_counts of 0        77000.0
# 1       113000.0
# 2       110000.0
# 3       151000.0
# 4        59000.0
#           ...
# 1120    173000.0
# 1121     50000.0
# 1122     76000.0
# 1123    137000.0
# 1124     93000.0
# Name: fea_4, Length: 1125, dtype: float64>
# <bound method IndexOpsMixin.value_counts of 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 1120    2
# 1121    2
# 1122    2
# 1123    2
# 1124    2
# Name: fea_5, Length: 1125, dtype: int64>
# <bound method IndexOpsMixin.value_counts of 0       15
# 1        8
# 2       11
# 3       11
# 4       11
#         ..
# 1120    15
# 1121    15
# 1122    11
# 1123     8
# 1124     8
# Name: fea_6, Length: 1125, dtype: int64>
# <bound method IndexOpsMixin.value_counts of 0       5
# 1      -1
# 2      -1
# 3       5
# 4       5
#        ..
# 1120    5
# 1121    5
# 1122    2
# 1123    5
# 1124    5
# Name: fea_7, Length: 1125, dtype: int64>
# <bound method IndexOpsMixin.value_counts of 0       109
# 1       100
# 2       101
# 3       110
# 4       108
#        ...
# 1120    112
# 1121    108
# 1122     90
# 1123     90
# 1124    113
# Name: fea_8, Length: 1125, dtype: int64>
# <bound method IndexOpsMixin.value_counts of 0       5
# 1       3
# 2       5
# 3       3
# 4       4
#        ..
# 1120    3
# 1121    4
# 1122    5
# 1123    5
# 1124    4
# Name: fea_9, Length: 1125, dtype: int64>
# <bound method IndexOpsMixin.value_counts of 0       151300
# 1       341759
# 2        72001
# 3        60084
# 4       450081
#          ...
# 1120    350702
# 1121    450000
# 1122     71002
# 1123     72000
# 1124    151300
# Name: fea_10, Length: 1125, dtype: int64>
# <bound method IndexOpsMixin.value_counts of 0       244.948974
# 1       207.173840
# 2         1.000000
# 3         1.000000
# 4       197.403141
#            ...
# 1120    200.000000
# 1121    169.000000
# 1122      1.000000
# 1123      1.000000
# 1124    273.861279
# Name: fea_11, Length: 1125, dtype: float64>

# %%
df1.isnull().sum()
# Out:
# label       0
# id          0
# fea_1       0
# fea_2     149
# fea_3       0
# fea_4       0
# fea_5       0
# fea_6       0
# fea_7       0
# fea_8       0
# fea_9       0
# fea_10      0
# fea_11      0
# dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df1.corr(), annot=True)
plt.show()

# %%
for i in df1.columns:
    print('columns: ', i)
    sns.boxplot(df1[i])
    plt.show()
# Out:
# columns:  label
# columns:  id
# columns:  fea_1
# columns:  fea_2
# columns:  fea_3
# columns:  fea_4
# columns:  fea_5
# columns:  fea_6
# columns:  fea_7
# columns:  fea_8
# columns:  fea_9
# columns:  fea_10
# columns:  fea_11

# %%
from sklearn.impute import KNNImputer
impute = KNNImputer(n_neighbors = 3)
df1['fea_2'] = impute.fit_transform(df1[['fea_2']])

# %%
df1.isnull().sum()
# Out:
# label     0
# id        0
# fea_1     0
# fea_2     0
# fea_3     0
# fea_4     0
# fea_5     0
# fea_6     0
# fea_7     0
# fea_8     0
# fea_9     0
# fea_10    0
# fea_11    0
# dtype: int64

# %%
df1
# Out:
#       label        id  fea_1        fea_2  fea_3     fea_4  fea_5  fea_6  \
# 0         1  54982665      5  1245.500000      3   77000.0      2     15
# 1         0  59004779      4  1277.000000      1  113000.0      2      8
# 2         0  58990862      7  1298.000000      1  110000.0      2     11
# 3         1  58995168      7  1335.500000      1  151000.0      2     11
# 4         0  54987320      7  1283.911373      2   59000.0      2     11
# ...     ...       ...    ...          ...    ...       ...    ...    ...
# 1120      0  58988196      5  1289.000000      1  173000.0      2     15
# 1121      0  58987926      5  1283.911373      2   50000.0      2     15
# 1122      0  58995381      7  1220.000000      3   76000.0      2     11
# 1123      0  58998054      4  1250.000000      3  137000.0      2      8
# 1124      0  54989781      4  1415.000000      3   93000.0      2      8
#
#       fea_7  fea_8  fea_9  fea_10      fea_11
# 0         5    109      5  151300  244.948974
# 1        -1    100      3  341759  207.173840
# 2        -1    101      5   72001    1.000000
# 3         5    110      3   60084    1.000000
# 4         5    108      4  450081  197.403141
# ...     ...    ...    ...     ...         ...
# 1120      5    112      3  350702  200.000000
# 1121      5    108      4  450000  169.000000
# 1122      2     90      5   71002    1.000000
# 1123      5     90      5   72000    1.000000
# 1124      5    113      4  151300  273.861279
#
# [1125 rows x 13 columns]

# %%
df2
# Out:
#             id  OVD_t1  OVD_t2  OVD_t3  OVD_sum  pay_normal  prod_code  \
# 0     58987402       0       0       0        0           1         10
# 1     58995151       0       0       0        0           1          5
# 2     58997200       0       0       0        0           2          5
# 3     54988608       0       0       0        0           3         10
# 4     54987763       0       0       0        0           2         10
# ...        ...     ...     ...     ...      ...         ...        ...
# 8245  58995478       0       0       0        0           9         15
# 8246  54992408       0       0       0        0           1          2
# 8247  54988209       0       0       0        0           5         13
# 8248  54992408       0       0       0        0           1          2
# 8249  54989207       0       0       0        0           1          5
#
#       prod_limit update_date  new_balance  highest_balance report_date
# 0        16500.0  04/12/2016          0.0              NaN         NaN
# 1            NaN  04/12/2016     588720.0         491100.0         NaN
# 2            NaN  04/12/2016     840000.0         700500.0  22/04/2016
# 3        37400.0  03/12/2016       8425.2           7520.0  25/04/2016
# 4            NaN  03/12/2016      15147.6              NaN  26/04/2016
# ...          ...         ...          ...              ...         ...
# 8245         NaN         NaN          0.0              NaN         NaN
# 8246         NaN         NaN          0.0              NaN         NaN
# 8247         NaN         NaN      20654.4          33315.0         NaN
# 8248         NaN         NaN          0.0              NaN         NaN
# 8249         NaN         NaN     240000.0         200500.0         NaN
#
# [8250 rows x 12 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8250 entries, 0 to 8249
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               8250 non-null   int64
#  1   OVD_t1           8250 non-null   int64
#  2   OVD_t2           8250 non-null   int64
#  3   OVD_t3           8250 non-null   int64
#  4   OVD_sum          8250 non-null   int64
#  5   pay_normal       8250 non-null   int64
#  6   prod_code        8250 non-null   int64
#  7   prod_limit       2132 non-null   float64
#  8   update_date      8224 non-null   object
#  9   new_balance      8250 non-null   float64
#  10  highest_balance  7841 non-null   float64
#  11  report_date      7136 non-null   object
# dtypes: float64(3), int64(7), object(2)
# memory usage: 773.6+ KB

# %%
df2['update_date'] = pd.to_datetime(df2['update_date'],dayfirst=True)
print(df2['update_date'].dtype)
# Out:
# datetime64[ns]

# %%
df2.isnull().sum()
# Out:
# id                    0
# OVD_t1                0
# OVD_t2                0
# OVD_t3                0
# OVD_sum               0
# pay_normal            0
# prod_code             0
# prod_limit         6118
# update_date          26
# new_balance           0
# highest_balance     409
# report_date        1114
# dtype: int64

# %%
feature_data_count = df2.count()

print(feature_data_count)
# Out:
# id                 8250
# OVD_t1             8250
# OVD_t2             8250
# OVD_t3             8250
# OVD_sum            8250
# pay_normal         8250
# prod_code          8250
# prod_limit         2132
# update_date        8224
# new_balance        8250
# highest_balance    7841
# report_date        7136
# dtype: int64

# %%
import pandas as pd

# Assuming 'df2' is your DataFrame
df2['update_date'] = pd.to_datetime(df2['update_date'])

# Check if there are missing values in the 'update_date' column
missing_values = df2['update_date'].isnull().sum()
if missing_values > 0:
    print(f"There are {missing_values} missing values in the 'update_date' column.")
else:
    df2['year1'] = df2['update_date'].dt.year
    df2['month2'] = df2['update_date'].dt.month
    df2['day3'] = df2['update_date'].dt.day
# Out:
# There are 26 missing values in the 'update_date' column.

# %%
df2['report_year1'] = df2['update_date'].dt.year
df2['report_month'] = df2['update_date'].dt.month
df2['report_day'] = df2['update_date'].dt.day

# %%
df2['report_date'] = pd.to_datetime(df2['report_date'])  # Convert to datetime type

# Now you can use .dt accessor to extract year, month, and day
df2['year1'] = df2['report_date'].dt.year
df2['month2'] = df2['report_date'].dt.month
df2['day3'] = df2['report_date'].dt.day
# Out:
# C:\Users\deepu\AppData\Local\Temp\ipykernel_3016\105918802.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df2['report_date'] = pd.to_datetime(df2['report_date'])  # Convert to datetime type

# %%
df2['year1'] = df2['report_date'].dt.year
df2['month2'] = df2['report_date'].dt.month
df2['day3'] = df2['report_date'].dt.day

# %%
df2
# Out:
#             id  OVD_t1  OVD_t2  OVD_t3  OVD_sum  pay_normal  prod_code  \
# 0     58987402       0       0       0        0           1         10
# 1     58995151       0       0       0        0           1          5
# 2     58997200       0       0       0        0           2          5
# 3     54988608       0       0       0        0           3         10
# 4     54987763       0       0       0        0           2         10
# ...        ...     ...     ...     ...      ...         ...        ...
# 8245  58995478       0       0       0        0           9         15
# 8246  54992408       0       0       0        0           1          2
# 8247  54988209       0       0       0        0           5         13
# 8248  54992408       0       0       0        0           1          2
# 8249  54989207       0       0       0        0           1          5
#
#       prod_limit update_date  new_balance  highest_balance report_date  \
# 0        16500.0  2016-12-04          0.0              NaN         NaT
# 1            NaN  2016-12-04     588720.0         491100.0         NaT
# 2            NaN  2016-12-04     840000.0         700500.0  2016-04-22
# 3        37400.0  2016-12-03       8425.2           7520.0  2016-04-25
# 4            NaN  2016-12-03      15147.6              NaN  2016-04-26
# ...          ...         ...          ...              ...         ...
# 8245         NaN         NaT          0.0              NaN         NaT
# 8246         NaN         NaT          0.0              NaN         NaT
# 8247         NaN         NaT      20654.4          33315.0         NaT
# 8248         NaN         NaT          0.0              NaN         NaT
# 8249         NaN         NaT     240000.0         200500.0         NaT
#
#       report_year1  report_month  report_day   year1  month2  day3
# 0           2016.0          12.0         4.0     NaN     NaN   NaN
# 1           2016.0          12.0         4.0     NaN     NaN   NaN
# 2           2016.0          12.0         4.0  2016.0     4.0  22.0
# 3           2016.0          12.0         3.0  2016.0     4.0  25.0
# 4           2016.0          12.0         3.0  2016.0     4.0  26.0
# ...            ...           ...         ...     ...     ...   ...
# 8245           NaN           NaN         NaN     NaN     NaN   NaN
# 8246           NaN           NaN         NaN     NaN     NaN   NaN
# 8247           NaN           NaN         NaN     NaN     NaN   NaN
# 8248           NaN           NaN         NaN     NaN     NaN   NaN
# 8249           NaN           NaN         NaN     NaN     NaN   NaN
#
# [8250 rows x 18 columns]

# %%
from sklearn.impute import KNNImputer
impute = KNNImputer(n_neighbors= 3)
cols = ['report_year1','report_month','report_day']
df2[cols] = df2[cols].round()
for i in cols:
    df2[i] = impute.fit_transform(df2[[i]])

# %%
df2
# Out:
#             id  OVD_t1  OVD_t2  OVD_t3  OVD_sum  pay_normal  prod_code  \
# 0     58987402       0       0       0        0           1         10
# 1     58995151       0       0       0        0           1          5
# 2     58997200       0       0       0        0           2          5
# 3     54988608       0       0       0        0           3         10
# 4     54987763       0       0       0        0           2         10
# ...        ...     ...     ...     ...      ...         ...        ...
# 8245  58995478       0       0       0        0           9         15
# 8246  54992408       0       0       0        0           1          2
# 8247  54988209       0       0       0        0           5         13
# 8248  54992408       0       0       0        0           1          2
# 8249  54989207       0       0       0        0           1          5
#
#       prod_limit update_date  new_balance  highest_balance report_date  \
# 0        16500.0  2016-12-04          0.0              NaN         NaT
# 1            NaN  2016-12-04     588720.0         491100.0         NaT
# 2            NaN  2016-12-04     840000.0         700500.0  2016-04-22
# 3        37400.0  2016-12-03       8425.2           7520.0  2016-04-25
# 4            NaN  2016-12-03      15147.6              NaN  2016-04-26
# ...          ...         ...          ...              ...         ...
# 8245         NaN         NaT          0.0              NaN         NaT
# 8246         NaN         NaT          0.0              NaN         NaT
# 8247         NaN         NaT      20654.4          33315.0         NaT
# 8248         NaN         NaT          0.0              NaN         NaT
# 8249         NaN         NaT     240000.0         200500.0         NaT
#
#       report_year1  report_month  report_day   year1  month2  day3
# 0      2016.000000     12.000000    4.000000     NaN     NaN   NaN
# 1      2016.000000     12.000000    4.000000     NaN     NaN   NaN
# 2      2016.000000     12.000000    4.000000  2016.0     4.0  22.0
# 3      2016.000000     12.000000    3.000000  2016.0     4.0  25.0
# 4      2016.000000     12.000000    3.000000  2016.0     4.0  26.0
# ...            ...           ...         ...     ...     ...   ...
# 8245   2011.617339      6.533074   15.176435     NaN     NaN   NaN
# 8246   2011.617339      6.533074   15.176435     NaN     NaN   NaN
# 8247   2011.617339      6.533074   15.176435     NaN     NaN   NaN
# 8248   2011.617339      6.533074   15.176435     NaN     NaN   NaN
# 8249   2011.617339      6.533074   15.176435     NaN     NaN   NaN
#
# [8250 rows x 18 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8250 entries, 0 to 8249
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               8250 non-null   int64
#  1   OVD_t1           8250 non-null   int64
#  2   OVD_t2           8250 non-null   int64
#  3   OVD_t3           8250 non-null   int64
#  4   OVD_sum          8250 non-null   int64
#  5   pay_normal       8250 non-null   int64
#  6   prod_code        8250 non-null   int64
#  7   prod_limit       2132 non-null   float64
#  8   update_date      8224 non-null   datetime64[ns]
#  9   new_balance      8250 non-null   float64
#  10  highest_balance  7841 non-null   float64
#  11  report_date      7136 non-null   datetime64[ns]
#  12  report_year1     8250 non-null   float64
#  13  report_month     8250 non-null   float64
#  14  report_day       8250 non-null   float64
#  15  year1            7136 non-null   float64
#  16  month2           7136 non-null   float64
#  17  day3             7136 non-null   float64
# dtypes: datetime64[ns](2), float64(9), int64(7)
# memory usage: 1.1 MB

# %%
df2.isnull().sum()
# Out:
# id                    0
# OVD_t1                0
# OVD_t2                0
# OVD_t3                0
# OVD_sum               0
# pay_normal            0
# prod_code             0
# prod_limit         6118
# update_date          26
# new_balance           0
# highest_balance     409
# report_date        1114
# report_year1          0
# report_month          0
# report_day            0
# year1              1114
# month2             1114
# day3               1114
# dtype: int64

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df2.corr(),annot=True)
plt.show()

# %%
from sklearn.impute import KNNImputer
impute = KNNImputer(n_neighbors= 3)
cols = ['year1','month2','day3']
df2[cols] = df2[cols].round()
for i in cols:
    df2[i] = impute.fit_transform(df2[[i]])

# %%
from sklearn.impute import KNNImputer
impute = KNNImputer(n_neighbors= 3)
cols = ['report_year1','report_month','report_day']
df2[cols] = df2[cols].round()
for i in cols:
    df2[i] = impute.fit_transform(df2[[i]])

# %%
df2
# Out:
#             id  OVD_t1  OVD_t2  OVD_t3  OVD_sum  pay_normal  prod_code  \
# 0     58987402       0       0       0        0           1         10
# 1     58995151       0       0       0        0           1          5
# 2     58997200       0       0       0        0           2          5
# 3     54988608       0       0       0        0           3         10
# 4     54987763       0       0       0        0           2         10
# ...        ...     ...     ...     ...      ...         ...        ...
# 8245  58995478       0       0       0        0           9         15
# 8246  54992408       0       0       0        0           1          2
# 8247  54988209       0       0       0        0           5         13
# 8248  54992408       0       0       0        0           1          2
# 8249  54989207       0       0       0        0           1          5
#
#       prod_limit update_date  new_balance  highest_balance report_date  \
# 0        16500.0  2016-12-04          0.0              NaN         NaT
# 1            NaN  2016-12-04     588720.0         491100.0         NaT
# 2            NaN  2016-12-04     840000.0         700500.0  2016-04-22
# 3        37400.0  2016-12-03       8425.2           7520.0  2016-04-25
# 4            NaN  2016-12-03      15147.6              NaN  2016-04-26
# ...          ...         ...          ...              ...         ...
# 8245         NaN         NaT          0.0              NaN         NaT
# 8246         NaN         NaT          0.0              NaN         NaT
# 8247         NaN         NaT      20654.4          33315.0         NaT
# 8248         NaN         NaT          0.0              NaN         NaT
# 8249         NaN         NaT     240000.0         200500.0         NaT
#
#       report_year1  report_month  report_day        year1   month2      day3
# 0           2016.0          12.0         4.0  2013.985706  6.36505  17.69829
# 1           2016.0          12.0         4.0  2013.985706  6.36505  17.69829
# 2           2016.0          12.0         4.0  2016.000000  4.00000  22.00000
# 3           2016.0          12.0         3.0  2016.000000  4.00000  25.00000
# 4           2016.0          12.0         3.0  2016.000000  4.00000  26.00000
# ...            ...           ...         ...          ...      ...       ...
# 8245        2012.0           7.0        15.0  2013.985706  6.36505  17.69829
# 8246        2012.0           7.0        15.0  2013.985706  6.36505  17.69829
# 8247        2012.0           7.0        15.0  2013.985706  6.36505  17.69829
# 8248        2012.0           7.0        15.0  2013.985706  6.36505  17.69829
# 8249        2012.0           7.0        15.0  2013.985706  6.36505  17.69829
#
# [8250 rows x 18 columns]

# %%
df2.isnull().sum()
# Out:
# id                    0
# OVD_t1                0
# OVD_t2                0
# OVD_t3                0
# OVD_sum               0
# pay_normal            0
# prod_code             0
# prod_limit         6118
# update_date          26
# new_balance           0
# highest_balance     409
# report_date        1114
# report_year1          0
# report_month          0
# report_day            0
# year1                 0
# month2                0
# day3                  0
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8250 entries, 0 to 8249
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               8250 non-null   int64
#  1   OVD_t1           8250 non-null   int64
#  2   OVD_t2           8250 non-null   int64
#  3   OVD_t3           8250 non-null   int64
#  4   OVD_sum          8250 non-null   int64
#  5   pay_normal       8250 non-null   int64
#  6   prod_code        8250 non-null   int64
#  7   prod_limit       2132 non-null   float64
#  8   update_date      8224 non-null   datetime64[ns]
#  9   new_balance      8250 non-null   float64
#  10  highest_balance  7841 non-null   float64
#  11  report_date      7136 non-null   datetime64[ns]
#  12  report_year1     8250 non-null   float64
#  13  report_month     8250 non-null   float64
#  14  report_day       8250 non-null   float64
#  15  year1            8250 non-null   float64
#  16  month2           8250 non-null   float64
#  17  day3             8250 non-null   float64
# dtypes: datetime64[ns](2), float64(9), int64(7)
# memory usage: 1.1 MB

# %%
for column in df2.columns:
    value_counts = df2[column].value_counts()
    print(f"Value counts for '{column}':\n{value_counts}\n")
# Out:
# Value counts for 'id':
# id
# 58988212    55
# 54990497    48
# 58998646    45
# 58991343    39
# 58987276    39
#             ..
# 59003280     1
# 58997216     1
# 54988258     1
# 58995803     1
# 54986089     1
# Name: count, Length: 1125, dtype: int64
#
# Value counts for 'OVD_t1':
# OVD_t1
# 0     7475
# 1      397
# 2      147
# 3       61
# 4       61
# 5       26
# 6       20
# 7       15
# 8       14
# 9        9
# 11       5
# 12       4
# 14       3
# 15       2
# 16       2
# 10       2
# 31       2
# 13       2
# 17       1
# 34       1
# 23       1
# Name: count, dtype: int64
#
# Value counts for 'OVD_t2':
# OVD_t2
# 0     7886
# 2      127
# 1      111
# 3       43
# 4       31
# 5       12
# 6        9
# 7        9
# 9        7
# 10       4
# 11       4
# 8        3
# 12       1
# 23       1
# 14       1
# 34       1
# Name: count, dtype: int64
#
# Value counts for 'OVD_t3':
# OVD_t3
# 0     7983
# 1       46
# 2       35
# 3       22
# 35      15
# 6       14
# 5       13
# 34      12
# 4       12
# 9       12
# 20       7
# 33       6
# 7        5
# 24       5
# 13       5
# 18       5
# 17       5
# 11       4
# 32       4
# 14       4
# 8        4
# 15       4
# 12       4
# 22       3
# 10       3
# 31       3
# 19       3
# 23       3
# 30       2
# 21       2
# 16       2
# 25       2
# 26       1
# Name: count, dtype: int64
#
# Value counts for 'OVD_sum':
# OVD_sum
# 0       7330
# 1         76
# 30        52
# 15        19
# 6         15
#         ...
# 96         1
# 97         1
# 3394       1
# 2269       1
# 690        1
# Name: count, Length: 393, dtype: int64
#
# Value counts for 'pay_normal':
# pay_normal
# 1     910
# 36    651
# 2     419
# 3     345
# 4     315
# 9     299
# 6     294
# 35    286
# 0     285
# 10    284
# 5     283
# 8     283
# 7     279
# 12    262
# 11    254
# 13    187
# 15    183
# 14    174
# 34    168
# 16    147
# 19    147
# 20    136
# 21    127
# 18    125
# 17    124
# 25    121
# 28    121
# 33    119
# 31    117
# 22    110
# 24    109
# 32    105
# 26    103
# 27    103
# 23    101
# 29     88
# 30     86
# Name: count, dtype: int64
#
# Value counts for 'prod_code':
# prod_code
# 10    4523
# 6     1144
# 5      962
# 1      427
# 13     425
# 2      239
# 0      147
# 7      147
# 12      56
# 19      35
# 24      24
# 8       24
# 15      22
# 17      22
# 3       21
# 26      14
# 25       5
# 4        4
# 22       3
# 9        3
# 27       3
# Name: count, dtype: int64
#
# Value counts for 'prod_limit':
# prod_limit
# 55000.0     103
# 11000.0      86
# 33000.0      51
# 27500.0      47
# 22000.0      46
#            ...
# 371800.0      1
# 321200.0      1
# 230175.0      1
# 35310.0       1
# 254100.0      1
# Name: count, Length: 321, dtype: int64
#
# Value counts for 'update_date':
# update_date
# 2012-10-30    22
# 2015-05-19    22
# 2015-01-16    20
# 2014-09-16    19
# 2015-02-16    17
#               ..
# 2009-09-08     1
# 2009-09-09     1
# 2009-09-11     1
# 2009-09-12     1
# 1988-07-19     1
# Name: count, Length: 3041, dtype: int64
#
# Value counts for 'new_balance':
# new_balance
#  0.0         3864
# -1.2           81
# -2.4           16
# -4.8           12
# -3.6           10
#              ...
#  7796.4         1
#  445034.4       1
#  111025.2       1
#  29221.2        1
#  20654.4        1
# Name: count, Length: 3939, dtype: int64
#
# Value counts for 'highest_balance':
# highest_balance
# 100500.0    151
# 150500.0    102
# 200500.0     84
# 30500.0      66
# 250500.0     54
#            ...
# 20168.0       1
# 57794.0       1
# 43918.0       1
# 190343.0      1
# 33315.0       1
# Name: count, Length: 5140, dtype: int64
#
# Value counts for 'report_date':
# report_date
# 2015-09-21    103
# 2015-11-21     64
# 2016-02-21     64
# 2016-01-18     57
# 2016-03-23     56
#              ...
# 2012-10-06      1
# 2013-02-03      1
# 2011-07-01      1
# 2011-12-20      1
# 1996-02-24      1
# Name: count, Length: 1862, dtype: int64
#
# Value counts for 'report_year1':
# report_year1
# 2015.0    1836
# 2014.0    1332
# 2013.0    1083
# 2012.0     681
# 2008.0     608
# 2007.0     515
# 2011.0     371
# 2016.0     345
# 2006.0     342
# 2009.0     338
# 2010.0     252
# 2005.0     236
# 2004.0     108
# 2003.0      67
# 2002.0      34
# 2001.0      29
# 2000.0      20
# 1997.0      15
# 1999.0      10
# 1998.0      10
# 1996.0       7
# 1994.0       4
# 1993.0       4
# 1995.0       1
# 1992.0       1
# 1988.0       1
# Name: count, dtype: int64
#
# Value counts for 'report_month':
# report_month
# 12.0    747
# 3.0     721
# 1.0     718
# 5.0     714
# 8.0     707
# 10.0    696
# 9.0     689
# 7.0     688
# 6.0     667
# 11.0    642
# 4.0     638
# 2.0     623
# Name: count, dtype: int64
#
# Value counts for 'report_day':
# report_day
# 16.0    468
# 15.0    384
# 17.0    328
# 18.0    319
# 19.0    310
# 5.0     303
# 11.0    301
# 12.0    301
# 2.0     296
# 9.0     281
# 14.0    280
# 4.0     278
# 1.0     278
# 6.0     277
# 26.0    266
# 10.0    260
# 13.0    259
# 7.0     256
# 8.0     248
# 3.0     244
# 23.0    243
# 27.0    242
# 28.0    235
# 29.0    231
# 24.0    228
# 30.0    226
# 25.0    223
# 21.0    196
# 22.0    189
# 20.0    180
# 31.0    120
# Name: count, dtype: int64
#
# Value counts for 'year1':
# year1
# 2015.000000    2497
# 2016.000000    2213
# 2013.985706    1114
# 2014.000000     536
# 2013.000000     385
# 2012.000000     354
# 2011.000000     267
# 2009.000000     234
# 2010.000000     231
# 2008.000000     161
# 2007.000000     118
# 2006.000000      73
# 2005.000000      47
# 2004.000000       7
# 2003.000000       4
# 2002.000000       3
# 2001.000000       2
# 1999.000000       2
# 2000.000000       1
# 1996.000000       1
# Name: count, dtype: int64
#
# Value counts for 'month2':
# month2
# 6.36505     1114
# 1.00000      799
# 11.00000     735
# 3.00000      722
# 2.00000      683
# 9.00000      642
# 12.00000     626
# 4.00000      615
# 10.00000     613
# 8.00000      477
# 5.00000      433
# 7.00000      398
# 6.00000      393
# Name: count, dtype: int64
#
# Value counts for 'day3':
# day3
# 17.69829    1114
# 21.00000     582
# 22.00000     448
# 23.00000     437
# 24.00000     431
# 18.00000     356
# 26.00000     345
# 25.00000     310
# 19.00000     297
# 16.00000     275
# 20.00000     274
# 27.00000     249
# 15.00000     210
# 2.00000      210
# 28.00000     202
# 3.00000      198
# 17.00000     197
# 10.00000     191
# 1.00000      189
# 12.00000     188
# 4.00000      188
# 11.00000     181
# 13.00000     178
# 14.00000     167
# 29.00000     155
# 5.00000      138
# 9.00000      124
# 30.00000     116
# 8.00000       83
# 7.00000       82
# 31.00000      68
# 6.00000       67
# Name: count, dtype: int64

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df2.corr(),annot=True)
plt.show()

# %%
cols = ['report_year1','report_month','report_day','year1','month2','day3']

for i in cols:
    df2[i] = df2[i].astype(int)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8250 entries, 0 to 8249
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               8250 non-null   int64
#  1   OVD_t1           8250 non-null   int64
#  2   OVD_t2           8250 non-null   int64
#  3   OVD_t3           8250 non-null   int64
#  4   OVD_sum          8250 non-null   int64
#  5   pay_normal       8250 non-null   int64
#  6   prod_code        8250 non-null   int64
#  7   prod_limit       2132 non-null   float64
#  8   update_date      8224 non-null   datetime64[ns]
#  9   new_balance      8250 non-null   float64
#  10  highest_balance  7841 non-null   float64
#  11  report_date      7136 non-null   datetime64[ns]
#  12  report_year1     8250 non-null   int32
#  13  report_month     8250 non-null   int32
#  14  report_day       8250 non-null   int32
#  15  year1            8250 non-null   int32
#  16  month2           8250 non-null   int32
#  17  day3             8250 non-null   int32
# dtypes: datetime64[ns](2), float64(3), int32(6), int64(7)
# memory usage: 966.9 KB

# %%
# Read the two datasets
df1 = pd.read_csv("E:\ml_fullstack_inter\data\customer_data.csv")
df2 = pd.read_csv("E:\ml_fullstack_inter\data\payment_data.csv")

# Merge the datasets based on a common key

merged_df = df1.merge(df2, on='id')

# %%
merged_df.drop(columns=['update_date','report_date'],inplace=True)

# %%
merged_df.isnull().sum()
# Out:
# label                 0
# id                    0
# fea_1                 0
# fea_2              1028
# fea_3                 0
# fea_4                 0
# fea_5                 0
# fea_6                 0
# fea_7                 0
# fea_8                 0
# fea_9                 0
# fea_10                0
# fea_11                0
# OVD_t1                0
# OVD_t2                0
# OVD_t3                0
# OVD_sum               0
# pay_normal            0
# prod_code             0
# prod_limit         6118
# new_balance           0
# highest_balance     409
# dtype: int64

# %%
from sklearn.impute import KNNImputer
impute = KNNImputer(n_neighbors= 3)
cols = ['prod_limit','highest_balance','fea_2']
merged_df[cols] = merged_df[cols].round()
for i in cols:
    merged_df[i] = impute.fit_transform(merged_df[[i]])

# %%
corr_matrix = merged_df.corr()
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
plt.figure(figsize=(20, 9))
plt.title("Correlation Heatmap", fontsize=16)
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr_matrix, mask=mask, cmap=cmap, annot=True, fmt=".2f", linewidths=0.5)
plt.xticks(rotation=45)
plt.show()

# %%
x = merged_df.drop(columns=['label'],axis=1)
y = merged_df['label']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y, test_size= 0.2)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(x,y, test_size= 0.2)

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(X_train,Y_train)

Y_pred_lr = lr.predict(X_test)

# %%
Y_pred_lr.shape
# Out:
# (1650,)

# %%
score_lr = round(accuracy_score(Y_pred_lr,Y_test)*100,2)

print("The accuracy score achieved using Logistic Regression is: "+str(score_lr)+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 82.79 %

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

nb.fit(X_train,Y_train)

Y_pred_nb = nb.predict(X_test)

# %%
Y_pred_nb.shape
# Out:
# (1650,)

# %%
score_nb = round(accuracy_score(Y_pred_nb,Y_test)*100,2)

print("The accuracy score achieved using Naive Bayes is: "+str(score_nb)+" %")
# Out:
# The accuracy score achieved using Naive Bayes is: 81.76 %

# %%
from sklearn.linear_model  import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
# Fit the logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Fit the random forest classifier
model1 = RandomForestClassifier()
model1.fit(X_train, y_train)

y_pred = model.predict(X_test)
predictions = model1.predict(X_test)

# %%
# Calculate accuracy
accuracy = accuracy_score(y_test,y_pred)
accuracy1 = accuracy_score(y_test,predictions)
print('logisticRegression:' )
print("Accuracy:", accuracy)
print()
print('RandomForestClassifier:' )
print("Accuracy:", accuracy1)
# Out:
# logisticRegression:
# Accuracy: 0.8284848484848485
#
# RandomForestClassifier:
# Accuracy: 0.8181818181818182

# %%
from sklearn.tree import DecisionTreeClassifier

max_accuracy = 0


for x in range(200):
    dt = DecisionTreeClassifier(random_state=x)
    dt.fit(X_train,Y_train)
    Y_pred_dt = dt.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_dt,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x
        
#print(max_accuracy)
#print(best_x)


dt = DecisionTreeClassifier(random_state=best_x)
dt.fit(X_train,Y_train)
Y_pred_dt = dt.predict(X_test)

# %%
print(Y_pred_dt.shape)
# Out:
# (1650,)

# %%
score_dt = round(accuracy_score(Y_pred_dt,Y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_dt)+" %")
# Out:
# The accuracy score achieved using Decision Tree is: 96.97 %

# %%
import xgboost as xgb

xgb_model = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
xgb_model.fit(X_train, Y_train)

Y_pred_xgb = xgb_model.predict(X_test)

# %%
Y_pred_xgb.shape
# Out:
# (1650,)

# %%
score_xgb = round(accuracy_score(Y_pred_xgb,Y_test)*100,2)

print("The accuracy score achieved using XGBoost is: "+str(score_xgb)+" %")
# Out:
# The accuracy score achieved using XGBoost is: 99.03 %

# %%
import pickle
with open('model2.pkl', 'wb') as f:
    pickle.dump(xgb_model,f)
